# %%
import great_expectations as gx
from pathlib import Path
import pandas as pd

# %%
context = gx.get_context(
    context_root_dir="../gx-data-context"
)

# %%
print("Data Context cargado desde:", context.root_directory)
# Out:
# Data Context cargado desde: /Users/alexander.pelaez/Desktop/pragma-data-lake/notebooks/../gx-data-context

# %% [markdown]
# ## Create Data Source

# %%
source_folder = "../data"

data_source_name = "my_filesystem_data_source_1"

# %%
data_source = context.data_sources.add_pandas_filesystem(
    name=data_source_name, base_directory=source_folder
)

# %% [markdown]
# ## Create a Data Asset

# %%
asset_name = "pragmaticos_test_parquet_file"

# %%
file_parquet_asset = data_source.add_parquet_asset(name=asset_name)

# %% [markdown]
# # Create a Batch Definition

# %%
file_data_asset = context.data_sources.get(data_source_name).get_asset(asset_name)

# %%
print(file_data_asset)
# Out:
# id: 84a0b58b-4fb4-416c-ac5a-911c8a6aee0a
# name: pragmaticos_test_parquet_file
# type: parquet

# %%
batch_definition_name = "batch_definition_1"

batch_definition_path = "pragmaticos_test.parquet"

# %%
batch_definition = file_data_asset.add_batch_definition_path(
    name=batch_definition_name, path=batch_definition_path
)

# %%
print(batch_definition)
# Out:
# id=UUID('d1c539d2-6b4d-4d61-8c4f-b3ff33b53da7') name='batch_definition_1' partitioner=FileNamePartitionerPath(regex=re.compile('pragmaticos_test.parquet$'), param_names=(), sort_ascending=True)

# %%
batch = batch_definition.get_batch()
print(batch.head())
# Out:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 410.48it/s]
#    sap_personal_id estado             correo_corporativo tipo_identificacion  \
# 0         10002910      t  nombre.apellido@pragma.com.co   CitizenshipCardID
# 1         10002913      t  nombre.apellido@pragma.com.co   CitizenshipCardID
# 2         10002916      t  nombre.apellido@pragma.com.co   CitizenshipCardID
# 3         10002919      t  nombre.apellido@pragma.com.co               CI ID
# 4         10002922      t  nombre.apellido@pragma.com.co   CitizenshipCardID
#
#   identificacion_nacional primer_nombre segundo_nombre primer_apellido  \
# 0             23546584654      Nombre 1       Nombre 2      Apellido 1
# 1              4654654654      Nombre 1       Nombre 2      Apellido 1
# 2                65464654      Nombre 1       Nombre 2      Apellido 1
# 3             8-6548-6546      Nombre 1       Nombre 2      Apellido 1
# 4                65464654      Nombre 1       Nombre 2      Apellido 1
#
#   segundo_apellido                  nombre_formal  ...         grupo_personal  \
# 0       Apellido 2  Luis Fernando Rodríguez Pérez  ...                Activos
# 1       Apellido 2     María José Sánchez Ramírez  ...  Aprendices y pasantes
# 2       Apellido 2    Juan Sebastián Morales Díaz  ...                Activos
# 3       Apellido 2        Ana Lucía Herrera Gómez  ...                Activos
# 4       Apellido 2     Carlos Andrés Navarro León  ...                Activos
#
#               lider_nombre    lider_id  division_personal  \
# 0         Rosalba de Armas  10000187.0  Colombia - Pragma
# 1   Oscar Alexander Orozco  10000621.0  Colombia - Pragma
# 2       Julián David Reyes  10000623.0  Colombia - Pragma
# 3  Diana del Pilar Ramirez  10000094.0         Costa Rica
# 4    Ana Paulina Echeverri  10000300.0  Colombia - Pragma
#
#            categoria_puesto                    kc              chapter  \
# 0     Operativos Asignables        Powerful Teams            Liderazgo
# 1              Practicantes      Computer Science              Backend
# 2     Operativos Asignables          Data Science     Ciencia de Datos
# 3  Transversales Operativos  Business Development   Business Developer
# 4     Operativos Asignables      Computer Science  Calidad de Software
#
#           especialidad tecnologia    seniority
# 0      Líder de Equipo       None  Advanced L3
# 1        Desarrollador       Java   Trainee L3
# 2  Científico de Datos       None    Senior L2
# 3               Hunter       None    Senior L1
# 4        Automatizador       None    Senior L1
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Create an expectation

# %%
from great_expectations import expectations as gxe

# %%
exp_1 = gxe.ExpectColumnValuesToNotBeNull(
    column="sap_personal_id"
)

# %%
validation_results_1 = batch.validate(exp_1)
# Out:
# Calculating Metrics: 100%|██████████| 8/8 [00:00<00:00, 516.19it/s]

# %%
print(validation_results_1)
# Out:
# {
#   "success": true,
#   "expectation_config": {
#     "type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#       "column": "sap_personal_id"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 27,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "partial_unexpected_counts": [],
#     "partial_unexpected_index_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
df = pd.read_parquet("/Users/alexander.pelaez/Desktop/pragma-data-lake/data/pragmaticos_test.parquet")

# %%
df.head()
# Out:
#    sap_personal_id estado             correo_corporativo tipo_identificacion  \
# 0         10002910      t  nombre.apellido@pragma.com.co   CitizenshipCardID
# 1         10002913      t  nombre.apellido@pragma.com.co   CitizenshipCardID
# 2         10002916      t  nombre.apellido@pragma.com.co   CitizenshipCardID
# 3         10002919      t  nombre.apellido@pragma.com.co               CI ID
# 4         10002922      t  nombre.apellido@pragma.com.co   CitizenshipCardID
#
#   identificacion_nacional primer_nombre segundo_nombre primer_apellido  \
# 0             23546584654      Nombre 1       Nombre 2      Apellido 1
# 1              4654654654      Nombre 1       Nombre 2      Apellido 1
# 2                65464654      Nombre 1       Nombre 2      Apellido 1
# 3             8-6548-6546      Nombre 1       Nombre 2      Apellido 1
# 4                65464654      Nombre 1       Nombre 2      Apellido 1
#
#   segundo_apellido                  nombre_formal  ...         grupo_personal  \
# 0       Apellido 2  Luis Fernando Rodríguez Pérez  ...                Activos
# 1       Apellido 2     María José Sánchez Ramírez  ...  Aprendices y pasantes
# 2       Apellido 2    Juan Sebastián Morales Díaz  ...                Activos
# 3       Apellido 2        Ana Lucía Herrera Gómez  ...                Activos
# 4       Apellido 2     Carlos Andrés Navarro León  ...                Activos
#
#               lider_nombre    lider_id  division_personal  \
# 0         Rosalba de Armas  10000187.0  Colombia - Pragma
# 1   Oscar Alexander Orozco  10000621.0  Colombia - Pragma
# 2       Julián David Reyes  10000623.0  Colombia - Pragma
# 3  Diana del Pilar Ramirez  10000094.0         Costa Rica
# 4    Ana Paulina Echeverri  10000300.0  Colombia - Pragma
#
#            categoria_puesto                    kc              chapter  \
# 0     Operativos Asignables        Powerful Teams            Liderazgo
# 1              Practicantes      Computer Science              Backend
# 2     Operativos Asignables          Data Science     Ciencia de Datos
# 3  Transversales Operativos  Business Development   Business Developer
# 4     Operativos Asignables      Computer Science  Calidad de Software
#
#           especialidad tecnologia    seniority
# 0      Líder de Equipo       None  Advanced L3
# 1        Desarrollador       Java   Trainee L3
# 2  Científico de Datos       None    Senior L2
# 3               Hunter       None    Senior L1
# 4        Automatizador       None    Senior L1
#
# [5 rows x 53 columns]

# %%
df.edad.max()
# Out:
# 43

# %% [markdown]
# ## Crear más expectativas y agregarlas a una suite

# %%
# Create expectation suite

suite_name = "my_expectation_suite_1"

suite = gx.ExpectationSuite(name=suite_name)

# %%
suite = context.suites.add(suite)

# %% [markdown]
# ### Crear más expectativas

# %%
exp_2 = gxe.ExpectColumnValuesToBeUnique(
    column="sap_personal_id"
)

exp_3 = gxe.ExpectColumnValuesToNotBeNull(
    column="correo_corporativo",
)

exp_4 = gxe.ExpectColumnValuesToNotBeNull(
    column="nacionalidad",
)

exp_5 = gxe.ExpectColumnValuesToNotBeNull(
    column="nacionalidad",
)

exp_6 = gxe.ExpectColumnValuesToNotBeNull(
    column="fecha_nacimiento",
)

exp_7 = gxe.ExpectColumnValuesToBeBetween(
    column="test2",
    min_value=18,
    max_value=40,
    strict_min=True,
    strict_max=True
)

# %% [markdown]
# ### Agregar las expectativas a la suite

# %%
expectativas = [exp_2, exp_3, exp_4, exp_5, exp_6, exp_7]

for expectativa in expectativas:
    suite.add_expectation(expectativa)
    
print(f"Se han agregado {len(expectativas)} expectativas a la suite.")
# Out:
# Se han agregado 6 expectativas a la suite.

# %%
exp_1.id = None

# %%
suite.add_expectation(exp_1)
# Out:
# ExpectColumnValuesToNotBeNull(id='b440c134-43cb-44be-9c2d-03d04d493e3c', meta=None, notes=None, result_format=<ResultFormat.BASIC: 'BASIC'>, description=None, catch_exceptions=True, rendered_content=None, windows=None, batch_id=None, column='sap_personal_id', mostly=1, row_condition=None, condition_parser=None)

# %%
print(suite)
# Out:
# {
#   "name": "my_expectation_suite_1",
#   "id": "10be34aa-102d-4436-a69a-53f535572186",
#   "expectations": [
#     {
#       "type": "expect_column_values_to_be_unique",
#       "kwargs": {
#         "column": "sap_personal_id"
#       },
#       "meta": {},
#       "id": "9c4f03e6-d20d-4907-9fa7-f32fca3ca4b0"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "correo_corporativo"
#       },
#       "meta": {},
#       "id": "6e83979b-2348-43ca-8278-0d97e1b213e9"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "nacionalidad"
#       },
#       "meta": {},
#       "id": "390a9650-502c-4cbc-93a5-174bd6b59edd"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "fecha_nacimiento"
#       },
#       "meta": {},
#       "id": "b16be408-8d4f-4fa3-a881-1f476b6d3037"
#     },
#     {
#       "type": "expect_column_values_to_be_between",
#       "kwargs": {
#         "column": "test2",
#         "min_value": 18.0,
#         "max_value": 40.0,
#         "strict_min": true,
#         "strict_max": true
#       },
#       "meta": {},
#       "id": "6f86718d-ab3c-41ef-8139-222f569f4c6e"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "sap_personal_id"
#       },
#       "meta": {},
#       "id": "b440c134-43cb-44be-9c2d-03d04d493e3c"
#     }
#   ],
#   "meta": {
#     "great_expectations_version": "1.4.2"
#   },
#   "notes": null
# }

# %% [markdown]
# ## Crear Validation Definition

# %%
definition_name = "my_validation_definition_1"

validation_definition = gx.ValidationDefinition(
    data=batch_definition, suite=suite, name=definition_name
)

# %%
validation_definition = context.validation_definitions.add(validation_definition)

# %%
validation_results = validation_definition.run()
# Out:
# Calculating Metrics:  80%|████████  | 28/35 [00:00<00:00, 1171.10it/s]

# %%
print(validation_results)
# Out:
# {
#   "success": false,
#   "results": [
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "test2",
#           "min_value": 18.0,
#           "max_value": 40.0,
#           "strict_min": true,
#           "strict_max": true,
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file"
#         },
#         "meta": {},
#         "id": "6f86718d-ab3c-41ef-8139-222f569f4c6e"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "MetricConfigurationID(metric_name='column_values.nonnull.condition', metric_domain_kwargs_id='3182b2260ed7fe3ff61e87107236e3f1', metric_value_kwargs_id=())": {
#           "exception_traceback": "Traceback (most recent call last):\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/execution_engine/execution_engine.py\", line 534, in _process_direct_and_bundled_metric_computation_configurations\n    metric_computation_configuration.metric_fn(  # type: ignore[misc] # F not callable\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/metric_provider.py\", line 99, in inner_func\n    return metric_fn(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/map_metric_provider/column_condition_partial.py\", line 92, in inner_func\n    metric_domain_kwargs = get_dbms_compatible_metric_domain_kwargs(\n                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/util.py\", line 685, in get_dbms_compatible_metric_domain_kwargs\n    column_name: str | sqlalchemy.quoted_name = get_dbms_compatible_column_names(\n                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/util.py\", line 755, in get_dbms_compatible_column_names\n    _verify_column_names_exist_and_get_normalized_typed_column_names_map(\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/util.py\", line 840, in _verify_column_names_exist_and_get_normalized_typed_column_names_map\n    raise gx_exceptions.InvalidMetricAccessorDomainKwargsKeyError(\ngreat_expectations.exceptions.exceptions.InvalidMetricAccessorDomainKwargsKeyError: Error: The column \"test2\" in BatchData does not exist.\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/validator/validation_graph.py\", line 286, in _resolve\n    self._execution_engine.resolve_metrics(\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/execution_engine/execution_engine.py\", line 280, in resolve_metrics\n    return self._process_direct_and_bundled_metric_computation_configurations(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/execution_engine/execution_engine.py\", line 539, in _process_direct_and_bundled_metric_computation_configurations\n    raise gx_exceptions.MetricResolutionError(\ngreat_expectations.exceptions.exceptions.MetricResolutionError: Error: The column \"test2\" in BatchData does not exist.\n",
#           "exception_message": "Error: The column \"test2\" in BatchData does not exist.",
#           "raised_exception": true
#         },
#         "MetricConfigurationID(metric_name='column_values.between.condition', metric_domain_kwargs_id='3182b2260ed7fe3ff61e87107236e3f1', metric_value_kwargs_id='eee0fd49fd10dd9c0f53068bf9862380')": {
#           "exception_traceback": "Traceback (most recent call last):\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/execution_engine/execution_engine.py\", line 534, in _process_direct_and_bundled_metric_computation_configurations\n    metric_computation_configuration.metric_fn(  # type: ignore[misc] # F not callable\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/metric_provider.py\", line 99, in inner_func\n    return metric_fn(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/map_metric_provider/column_condition_partial.py\", line 92, in inner_func\n    metric_domain_kwargs = get_dbms_compatible_metric_domain_kwargs(\n                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/util.py\", line 685, in get_dbms_compatible_metric_domain_kwargs\n    column_name: str | sqlalchemy.quoted_name = get_dbms_compatible_column_names(\n                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/util.py\", line 755, in get_dbms_compatible_column_names\n    _verify_column_names_exist_and_get_normalized_typed_column_names_map(\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/expectations/metrics/util.py\", line 840, in _verify_column_names_exist_and_get_normalized_typed_column_names_map\n    raise gx_exceptions.InvalidMetricAccessorDomainKwargsKeyError(\ngreat_expectations.exceptions.exceptions.InvalidMetricAccessorDomainKwargsKeyError: Error: The column \"test2\" in BatchData does not exist.\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/validator/validation_graph.py\", line 286, in _resolve\n    self._execution_engine.resolve_metrics(\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/execution_engine/execution_engine.py\", line 280, in resolve_metrics\n    return self._process_direct_and_bundled_metric_computation_configurations(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/Users/alexander.pelaez/Desktop/pragma-data-lake/.venv/lib/python3.12/site-packages/great_expectations/execution_engine/execution_engine.py\", line 539, in _process_direct_and_bundled_metric_computation_configurations\n    raise gx_exceptions.MetricResolutionError(\ngreat_expectations.exceptions.exceptions.MetricResolutionError: Error: The column \"test2\" in BatchData does not exist.\n",
#           "exception_message": "Error: The column \"test2\" in BatchData does not exist.",
#           "raised_exception": true
#         }
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_unique",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "sap_personal_id"
#         },
#         "meta": {},
#         "id": "9c4f03e6-d20d-4907-9fa7-f32fca3ca4b0"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "sap_personal_id"
#         },
#         "meta": {},
#         "id": "b440c134-43cb-44be-9c2d-03d04d493e3c"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "correo_corporativo"
#         },
#         "meta": {},
#         "id": "6e83979b-2348-43ca-8278-0d97e1b213e9"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "nacionalidad"
#         },
#         "meta": {},
#         "id": "390a9650-502c-4cbc-93a5-174bd6b59edd"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 1,
#         "unexpected_percent": 3.7037037037037033,
#         "partial_unexpected_list": [
#           null
#         ],
#         "partial_unexpected_counts": [
#           {
#             "value": null,
#             "count": 1
#           }
#         ],
#         "partial_unexpected_index_list": [
#           11
#         ]
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "fecha_nacimiento"
#         },
#         "meta": {},
#         "id": "b16be408-8d4f-4fa3-a881-1f476b6d3037"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "my_expectation_suite_1",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 6,
#     "successful_expectations": 4,
#     "unsuccessful_expectations": 2,
#     "success_percent": 66.66666666666666
#   },
#   "meta": {
#     "great_expectations_version": "1.4.2",
#     "batch_spec": {
#       "path": "../data/pragmaticos_test.parquet",
#       "reader_method": "read_parquet",
#       "reader_options": {}
#     },
#     "batch_markers": {
#       "ge_load_time": "20250504T013026.799482Z",
#       "pandas_data_fingerprint": "552e97de7ad187f63dad893576d5d82d"
#     },
#     "active_batch_definition": {
#       "datasource_name": "my_filesystem_data_source_1",
#       "data_connector_name": "fluent",
#       "data_asset_name": "pragmaticos_test_parquet_file",
#       "batch_identifiers": {
#         "path": "pragmaticos_test.parquet"
#       },
#       "batching_regex": "(?P<path>pragmaticos_test.parquet$)"
#     },
#     "validation_id": "4e7d520b-cbed-476e-afc0-4836d4c7f568",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-05-03T20:30:26.925314-05:00"
#     },
#     "validation_time": "2025-05-04T01:30:26.925314+00:00",
#     "batch_parameters": null
#   },
#   "id": null
# }

# %%
exp_7.column="edad"
exp_7.save()

# %%
validation_results = validation_definition.run()
# Out:
# Calculating Metrics: 100%|██████████| 35/35 [00:00<00:00, 5827.27it/s]

# %%
print(validation_results)
# Out:
# {
#   "success": false,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_unique",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "sap_personal_id"
#         },
#         "meta": {},
#         "id": "9c4f03e6-d20d-4907-9fa7-f32fca3ca4b0"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "sap_personal_id"
#         },
#         "meta": {},
#         "id": "b440c134-43cb-44be-9c2d-03d04d493e3c"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "correo_corporativo"
#         },
#         "meta": {},
#         "id": "6e83979b-2348-43ca-8278-0d97e1b213e9"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "nacionalidad"
#         },
#         "meta": {},
#         "id": "390a9650-502c-4cbc-93a5-174bd6b59edd"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 1,
#         "unexpected_percent": 3.7037037037037033,
#         "partial_unexpected_list": [
#           null
#         ],
#         "partial_unexpected_counts": [
#           {
#             "value": null,
#             "count": 1
#           }
#         ],
#         "partial_unexpected_index_list": [
#           11
#         ]
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "fecha_nacimiento"
#         },
#         "meta": {},
#         "id": "b16be408-8d4f-4fa3-a881-1f476b6d3037"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "edad",
#           "min_value": 18.0,
#           "max_value": 40.0,
#           "strict_min": true,
#           "strict_max": true
#         },
#         "meta": {},
#         "id": "6f86718d-ab3c-41ef-8139-222f569f4c6e"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 7,
#         "unexpected_percent": 25.925925925925924,
#         "partial_unexpected_list": [
#           15,
#           17,
#           42,
#           43,
#           16,
#           16,
#           17
#         ],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 25.925925925925924,
#         "unexpected_percent_nonmissing": 25.925925925925924,
#         "partial_unexpected_counts": [
#           {
#             "value": 16,
#             "count": 2
#           },
#           {
#             "value": 17,
#             "count": 2
#           },
#           {
#             "value": 15,
#             "count": 1
#           },
#           {
#             "value": 42,
#             "count": 1
#           },
#           {
#             "value": 43,
#             "count": 1
#           }
#         ],
#         "partial_unexpected_index_list": [
#           1,
#           7,
#           13,
#           14,
#           15,
#           17,
#           22
#         ]
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "my_expectation_suite_1",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 6,
#     "successful_expectations": 4,
#     "unsuccessful_expectations": 2,
#     "success_percent": 66.66666666666666
#   },
#   "meta": {
#     "great_expectations_version": "1.4.2",
#     "batch_spec": {
#       "path": "../data/pragmaticos_test.parquet",
#       "reader_method": "read_parquet",
#       "reader_options": {}
#     },
#     "batch_markers": {
#       "ge_load_time": "20250504T013234.189384Z",
#       "pandas_data_fingerprint": "552e97de7ad187f63dad893576d5d82d"
#     },
#     "active_batch_definition": {
#       "datasource_name": "my_filesystem_data_source_1",
#       "data_connector_name": "fluent",
#       "data_asset_name": "pragmaticos_test_parquet_file",
#       "batch_identifiers": {
#         "path": "pragmaticos_test.parquet"
#       },
#       "batching_regex": "(?P<path>pragmaticos_test.parquet$)"
#     },
#     "validation_id": "4e7d520b-cbed-476e-afc0-4836d4c7f568",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-05-03T20:32:34.277118-05:00"
#     },
#     "validation_time": "2025-05-04T01:32:34.277118+00:00",
#     "batch_parameters": null
#   },
#   "id": null
# }

# %% [markdown]
# ## Crear un checkpoint con acciones

# %%
from great_expectations.checkpoint import UpdateDataDocsAction

# %%
validation_definitions_ = [
    context.validation_definitions.get(name="my_validation_definition_1")
]

# %%
action_list = [
    UpdateDataDocsAction(
        name="update_all_data_docs"
    )
]

# %%
# Crear el checkpoint

checkpoint_name = "my_checkpoint_1"

checkpoint = gx.Checkpoint(
    name=checkpoint_name,
    validation_definitions=validation_definitions_,
    actions=action_list,
    result_format={"result_format": "COMPLETE"},
)

# %%
# Guardar el checkpoint en el data context

context.checkpoints.add(checkpoint)
# Out:
# Checkpoint(name='my_checkpoint_1', validation_definitions=[ValidationDefinition(name='my_validation_definition_1', data=BatchDefinition(id=UUID('d1c539d2-6b4d-4d61-8c4f-b3ff33b53da7'), name='batch_definition_1', partitioner=FileNamePartitionerPath(regex=re.compile('pragmaticos_test.parquet$'), param_names=(), sort_ascending=True)), suite={
#   "name": "my_expectation_suite_1",
#   "id": "10be34aa-102d-4436-a69a-53f535572186",
#   "expectations": [
#     {
#       "type": "expect_column_values_to_be_unique",
#       "kwargs": {
#         "column": "sap_personal_id"
#       },
#       "meta": {},
#       "id": "9c4f03e6-d20d-4907-9fa7-f32fca3ca4b0"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "correo_corporativo"
#       },
#       "meta": {},
#       "id": "6e83979b-2348-43ca-8278-0d97e1b213e9"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "nacionalidad"
#       },
#       "meta": {},
#       "id": "390a9650-502c-4cbc-93a5-174bd6b59edd"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "fecha_nacimiento"
#       },
#       "meta": {},
#       "id": "b16be408-8d4f-4fa3-a881-1f476b6d3037"
#     },
#     {
#       "type": "expect_column_values_to_be_between",
#       "kwargs": {
#         "column": "edad",
#         "min_value": 18.0,
#         "max_value": 40.0,
#         "strict_min": true,
#         "strict_max": true
#       },
#       "meta": {},
#       "id": "6f86718d-ab3c-41ef-8139-222f569f4c6e"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "sap_personal_id"
#       },
#       "meta": {},
#       "id": "b440c134-43cb-44be-9c2d-03d04d493e3c"
#     }
#   ],
#   "meta": {
#     "great_expectations_version": "1.4.2"
#   },
#   "notes": null
# }, id='4e7d520b-cbed-476e-afc0-4836d4c7f568')], actions=[UpdateDataDocsAction(type='update_data_docs', name='update_all_data_docs', site_names=[])], result_format={'result_format': 'COMPLETE'}, id='6597c0d7-548a-4489-a87e-f21b45e4478a')

# %%
validation_results = checkpoint.run()
# Out:
# Calculating Metrics: 100%|██████████| 35/35 [00:00<00:00, 5702.32it/s]

# %%
print(validation_results)
# Out:
# run_id={"run_name": null, "run_time": "2025-05-03T20:55:55.959444-05:00"} run_results={ValidationResultIdentifier::my_expectation_suite_1/__none__/20250504T015555.959444Z/my_filesystem_data_source_1-pragmaticos_test_parquet_file: {
#   "success": false,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_unique",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "sap_personal_id"
#         },
#         "meta": {},
#         "id": "9c4f03e6-d20d-4907-9fa7-f32fca3ca4b0"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": [],
#         "unexpected_list": [],
#         "unexpected_index_list": [],
#         "unexpected_index_query": "df.filter(items=[], axis=0)"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "sap_personal_id"
#         },
#         "meta": {},
#         "id": "b440c134-43cb-44be-9c2d-03d04d493e3c"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": [],
#         "unexpected_list": [],
#         "unexpected_index_list": [],
#         "unexpected_index_query": "df.filter(items=[], axis=0)"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "correo_corporativo"
#         },
#         "meta": {},
#         "id": "6e83979b-2348-43ca-8278-0d97e1b213e9"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": [],
#         "unexpected_list": [],
#         "unexpected_index_list": [],
#         "unexpected_index_query": "df.filter(items=[], axis=0)"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "nacionalidad"
#         },
#         "meta": {},
#         "id": "390a9650-502c-4cbc-93a5-174bd6b59edd"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 1,
#         "unexpected_percent": 3.7037037037037033,
#         "partial_unexpected_list": [
#           null
#         ],
#         "partial_unexpected_counts": [
#           {
#             "value": null,
#             "count": 1
#           }
#         ],
#         "partial_unexpected_index_list": [
#           11
#         ],
#         "unexpected_list": [
#           null
#         ],
#         "unexpected_index_list": [
#           11
#         ],
#         "unexpected_index_query": "df.filter(items=[11], axis=0)"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "fecha_nacimiento"
#         },
#         "meta": {},
#         "id": "b16be408-8d4f-4fa3-a881-1f476b6d3037"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": [],
#         "unexpected_list": [],
#         "unexpected_index_list": [],
#         "unexpected_index_query": "df.filter(items=[], axis=0)"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "my_filesystem_data_source_1-pragmaticos_test_parquet_file",
#           "column": "edad",
#           "min_value": 18.0,
#           "max_value": 40.0,
#           "strict_min": true,
#           "strict_max": true
#         },
#         "meta": {},
#         "id": "6f86718d-ab3c-41ef-8139-222f569f4c6e"
#       },
#       "result": {
#         "element_count": 27,
#         "unexpected_count": 7,
#         "unexpected_percent": 25.925925925925924,
#         "partial_unexpected_list": [
#           15,
#           17,
#           42,
#           43,
#           16,
#           16,
#           17
#         ],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 25.925925925925924,
#         "unexpected_percent_nonmissing": 25.925925925925924,
#         "partial_unexpected_counts": [
#           {
#             "value": 16,
#             "count": 2
#           },
#           {
#             "value": 17,
#             "count": 2
#           },
#           {
#             "value": 15,
#             "count": 1
#           },
#           {
#             "value": 42,
#             "count": 1
#           },
#           {
#             "value": 43,
#             "count": 1
#           }
#         ],
#         "partial_unexpected_index_list": [
#           1,
#           7,
#           13,
#           14,
#           15,
#           17,
#           22
#         ],
#         "unexpected_list": [
#           15,
#           17,
#           42,
#           43,
#           16,
#           16,
#           17
#         ],
#         "unexpected_index_list": [
#           1,
#           7,
#           13,
#           14,
#           15,
#           17,
#           22
#         ],
#         "unexpected_index_query": "df.filter(items=[1, 7, 13, 14, 15, 17, 22], axis=0)"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "my_expectation_suite_1",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 6,
#     "successful_expectations": 4,
#     "unsuccessful_expectations": 2,
#     "success_percent": 66.66666666666666
#   },
#   "meta": {
#     "great_expectations_version": "1.4.2",
#     "batch_spec": {
#       "path": "../data/pragmaticos_test.parquet",
#       "reader_method": "read_parquet",
#       "reader_options": {}
#     },
#     "batch_markers": {
#       "ge_load_time": "20250504T015555.967947Z",
#       "pandas_data_fingerprint": "552e97de7ad187f63dad893576d5d82d"
#     },
#     "active_batch_definition": {
#       "datasource_name": "my_filesystem_data_source_1",
#       "data_connector_name": "fluent",
#       "data_asset_name": "pragmaticos_test_parquet_file",
#       "batch_identifiers": {
#         "path": "pragmaticos_test.parquet"
#       },
#       "batching_regex": "(?P<path>pragmaticos_test.parquet$)"
#     },
#     "validation_id": "4e7d520b-cbed-476e-afc0-4836d4c7f568",
#     "checkpoint_id": "6597c0d7-548a-4489-a87e-f21b45e4478a",
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-05-03T20:55:55.959444-05:00"
#     },
#     "validation_time": "2025-05-04T01:55:55.959444+00:00",
#     "batch_parameters": null
#   },
#   "id": null
# }} checkpoint_config=Checkpoint(name='my_checkpoint_1', validation_definitions=[ValidationDefinition(name='my_validation_definition_1', data=BatchDefinition(id=UUID('d1c539d2-6b4d-4d61-8c4f-b3ff33b53da7'), name='batch_definition_1', partitioner=FileNamePartitionerPath(regex=re.compile('pragmaticos_test.parquet$'), param_names=(), sort_ascending=True)), suite={
#   "name": "my_expectation_suite_1",
#   "id": "10be34aa-102d-4436-a69a-53f535572186",
#   "expectations": [
#     {
#       "type": "expect_column_values_to_be_unique",
#       "kwargs": {
#         "column": "sap_personal_id"
#       },
#       "meta": {},
#       "id": "9c4f03e6-d20d-4907-9fa7-f32fca3ca4b0"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "correo_corporativo"
#       },
#       "meta": {},
#       "id": "6e83979b-2348-43ca-8278-0d97e1b213e9"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "nacionalidad"
#       },
#       "meta": {},
#       "id": "390a9650-502c-4cbc-93a5-174bd6b59edd"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "fecha_nacimiento"
#       },
#       "meta": {},
#       "id": "b16be408-8d4f-4fa3-a881-1f476b6d3037"
#     },
#     {
#       "type": "expect_column_values_to_be_between",
#       "kwargs": {
#         "column": "edad",
#         "min_value": 18.0,
#         "max_value": 40.0,
#         "strict_min": true,
#         "strict_max": true
#       },
#       "meta": {},
#       "id": "6f86718d-ab3c-41ef-8139-222f569f4c6e"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "sap_personal_id"
#       },
#       "meta": {},
#       "id": "b440c134-43cb-44be-9c2d-03d04d493e3c"
#     }
#   ],
#   "meta": {
#     "great_expectations_version": "1.4.2"
#   },
#   "notes": null
# }, id='4e7d520b-cbed-476e-afc0-4836d4c7f568')], actions=[UpdateDataDocsAction(type='update_data_docs', name='update_all_data_docs', site_names=[])], result_format={'result_format': 'COMPLETE'}, id='6597c0d7-548a-4489-a87e-f21b45e4478a') success=False

# %%
context.open_data_docs()

# %%
print(context.variables.config.stores["expectations_store"])
print(context.variables.config.stores["validation_definition_store"])
print(context.variables.config.stores["checkpoint_store"])
print(context.variables.config.stores["validation_results_store"])
# Out:
# {'class_name': 'ExpectationsStore', 'store_backend': {'class_name': 'TupleFilesystemStoreBackend', 'base_directory': 'expectations/'}}
# {'class_name': 'ValidationDefinitionStore', 'store_backend': {'class_name': 'TupleFilesystemStoreBackend', 'base_directory': 'validation_definitions/'}}
# {'class_name': 'CheckpointStore', 'store_backend': {'class_name': 'TupleFilesystemStoreBackend', 'suppress_store_backend_id': True, 'base_directory': 'checkpoints/'}}
# {'class_name': 'ValidationResultsStore', 'store_backend': {'class_name': 'TupleFilesystemStoreBackend', 'base_directory': 'uncommitted/validations/'}}
